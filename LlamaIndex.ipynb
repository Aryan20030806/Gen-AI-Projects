# %% [markdown]
# **STEP 1 - DONWLOADING THE REQ PACK AND LIB**

# %%
# !pip install llama-index
# !pip install 'google-generativeai>=0.3.0'
# !pip install llama-index-multi-modal-llms-gemini
# !pip install llama-index-embeddings-gemini
# !pip install llama-index-vector-stores-memory
# !pip install sentence-transformers
# !pip install Pillow
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-huggingface
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement llama-index-vector-stores-memory (from versions: none)
# ERROR: No matching distribution found for llama-index-vector-stores-memory
# ...

# %%
import os
from getpass import getpass
import google.generativeai as genai
from llama_index.core import StorageContext, VectorStoreIndex
from llama_index.multi_modal_llms.gemini import GeminiMultiModal
from llama_index.llms.gemini import Gemini
from llama_index.core import SimpleDirectoryReader
from langchain_huggingface import HuggingFaceEmbeddings
from pydantic import BaseModel
from PIL import Image
import matplotlib.pyplot as plt
from llama_index.core import Settings

# %% [markdown]
# **STEP 2 - LOADING THE GEMINI AND HF KEY**

# %%
GOOGLE_API_KEY = ""
HUGGINGFACE_API_KEY = ""
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
os.environ["HUGGINGFACE_API_KEY"] = HUGGINGFACE_API_KEY
# Out:
# AIzaSyCTKG-UmUxPQv3yAXcFQI9_1ZE1Wx4zFMI··········

# %% [markdown]
# **STEP 3 - LOADING THE DOCUMENTS**

# %%
# !mkdir data

# %%
documents = SimpleDirectoryReader("/content/data")
documents = documents.load_data()

# %%
documents = SimpleDirectoryReader("/content/data").load_data()

# %% [markdown]
# **STEP 4 - SETTING UP THE EMBEDDING MODEL**

# %%
embed_model = HuggingFaceEmbeddings(
    model_name="models/embedding-001", api_key= HUGGINGFACE_API_KEY
)
llm = Gemini(api_key=GOOGLE_API_KEY)
# Out:
# /tmp/ipython-input-3464703132.py:1: DeprecationWarning: Call to deprecated class GeminiEmbedding. (Should use `llama-index-embeddings-google-genai` instead, using Google's latest unified SDK. See: https://docs.llamaindex.ai/en/stable/examples/embeddings/google_genai/)
#   Settings.embed_model = GeminiEmbedding(
# /tmp/ipython-input-3464703132.py:4: DeprecationWarning: Call to deprecated class Gemini. (Should use `llama-index-llms-google-genai` instead, using Google's latest unified SDK. See: https://docs.llamaindex.ai/en/stable/examples/llm/google_genai/)
#   Settings.llm = Gemini(api_key=GOOGLE_API_KEY)

# %% [markdown]
# **STEP 5 - SETTING UP THE VECTOR STORAGE**

# %%
storage_context = StorageContext.from_defaults()

index = VectorStoreIndex.from_documents(
    documents=documents,
    storage_context=storage_context,
)

# %% [markdown]
# **STEP 6 - SETTING UP THE QUERY ENGINE**

# %%
query_engine = index.as_query_engine(similarity_top_k=3)
response = query_engine.query(
    "Summarize the document and provide key insights."
)
print(response)
